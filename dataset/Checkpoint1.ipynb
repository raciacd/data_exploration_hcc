# %%
#Libraries to be used
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#DATA EXPLORATION
# We explored:
# 1. The first 10 rows of the dataset
# 2. The shape of the dataset
# 3. The data types of the columns
# 4. The values in each collum and it's number of missing values
# 5. The behaviour of values in each column (especially the class distribution column) identifying outliers.

# DATA PREPROCESSING:
# 1. Transformed a column name to correct a typo
# 2. Corrected the data type for all columns
# 3. Transformed all missing values from '?' to NaN.

# Needed to decide:
# 1. How to handle missing values
# 2. How to handle outliers
# 3. How to handle class imbalance

# %%
# Load the dataset
df = pd.read_csv('hcc_dataset.csv')

# Display the first 10 rows of the dataframe
df.head(10)
# Out:
#    Gender Symptoms Alcohol HBsAg HBeAg HBcAb HCVAb Cirrhosis Endemic Smoking  \
# 0    Male       No     Yes    No    No    No    No       Yes      No     Yes
# 1  Female        ?      No    No    No    No   Yes       Yes       ?       ?
# 2    Male       No     Yes   Yes    No   Yes    No       Yes      No     Yes
# 3    Male      Yes     Yes    No    No    No    No       Yes      No     Yes
# 4    Male      Yes     Yes   Yes    No   Yes    No       Yes      No     Yes
# 5    Male       No     Yes    No     ?    No    No       Yes      No       ?
# 6    Male       No      No    No     ?   Yes   Yes       Yes      No      No
# 7    Male      Yes     Yes    No     ?    No    No       Yes      No     Yes
# 8    Male      Yes     Yes    No    No    No    No       Yes      No     Yes
# 9    Male      Yes     Yes    No    No    No    No       Yes      No      No
#
#   Diabetes Obesity Hemochro  AHT  CRI HIV NASH Varices Spleno  PHT  PVT  \
# 0      Yes       ?      Yes   No   No  No   No     Yes     No   No   No
# 1      Yes      No       No  Yes   No  No   No     Yes     No   No   No
# 2       No      No       No  Yes  Yes  No   No      No     No  Yes   No
# 3      Yes      No       No  Yes   No  No   No      No     No   No   No
# 4       No      No       No  Yes  Yes  No   No      No     No   No   No
# 5       No     Yes       No   No   No  No   No     Yes    Yes  Yes   No
# 6      Yes      No        ?   No   No  No   No      No     No   No   No
# 7      Yes       ?       No   No   No  No   No      No    Yes  Yes  Yes
# 8      Yes      No       No  Yes   No  No   No       ?    Yes  Yes   No
# 9       No      No      Yes   No   No  No   No      No    Yes   No   No
#
#   Metastasis Hallmark  Age Grams_day Packs_year          PS Encephalopathy  \
# 0         No      Yes   67       137         15      Active            NaN
# 1         No      Yes   62         0          ?      Active            NaN
# 2        Yes      Yes   78        50         50  Ambulatory            NaN
# 3        Yes      Yes   77        40         30      Active            NaN
# 4         No      Yes   76       100         30      Active            NaN
# 5         No      Yes   75         ?          ?  Restricted            NaN
# 6         No      Yes   49         0          0      Active            NaN
# 7         No      Yes   61         ?         20    Selfcare            NaN
# 8         No      Yes   50       100         32  Restricted            NaN
# 9         No       No   43       100          0      Active            NaN
#
#   Ascites   INR    AFP Hemoglobin    MCV Leucocytes Platelets  Albumin  \
# 0     NaN  1.53     95       13.7  106.6        4.9        99      3.4
# 1     NaN     ?      ?          ?      ?          ?         ?        ?
# 2    Mild  0.96    5.8        8.9   79.8        8.4       472      3.3
# 3     NaN  0.95   2440       13.4   97.1          9       279      3.7
# 4     NaN  0.94     49       14.3   95.1        6.4       199      4.1
# 5    Mild  1.58    110       13.4   91.5        5.4        85      3.4
# 6     NaN   1.4  138.9       10.4    102        3.2     42000     2.35
# 7     NaN  1.46   9860       10.8     92          3        58      3.1
# 8    Mild  3.14    8.8       11.9  107.5        4.9        70      1.9
# 9     NaN  1.12    1.8       11.8   87.8       5100    193000      4.2
#
#   Total_Bil  ALT  AST  GGT  ALP   TP Creatinine Nodules Major_Dim Dir_Bil  \
# 0       2.1   34   41  183  150  7.1        0.7       1       3.5     0.5
# 1         ?    ?    ?    ?    ?    ?          ?       1       1.8       ?
# 2       0.4   58   68  202  109    7        2.1       5        13     0.1
# 3       0.4   16   64   94  174  8.1       1.11       2      15.7     0.2
# 4       0.7  147  306  173  109  6.9        1.8       1         9       ?
# 5       3.5   91  122  242  396  5.6        0.9       1        10     1.4
# 6      2.72  119  183  143  211  7.3        0.8       5       2.6    2.19
# 7       3.2   79  108  184  300  7.1       0.52       2         9     1.3
# 8       3.3   26   59  115   63  6.1       0.59       1       6.4     1.2
# 9       0.5   71   45  256  303  7.1       0.59       1       9.3     0.7
#
#   Iron  Sat Ferritin  Class
# 0    ?    ?        ?  Lives
# 1    ?    ?        ?  Lives
# 2   28    6       16  Lives
# 3    ?    ?        ?   Dies
# 4   59   15       22  Lives
# 5   53   22      111   Dies
# 6  171  126     1452   Dies
# 7   42   25      706   Dies
# 8   85   73      982  Lives
# 9    ?    ?        ?  Lives

# %%
# Get a concise summary of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 50 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          165 non-null    object
#  1   Symptoms        165 non-null    object
#  2   Alcohol         165 non-null    object
#  3   HBsAg           165 non-null    object
#  4   HBeAg           165 non-null    object
#  5   HBcAb           165 non-null    object
#  6   HCVAb           165 non-null    object
#  7   Cirrhosis       165 non-null    object
#  8   Endemic         165 non-null    object
#  9   Smoking         165 non-null    object
#  10  Diabetes        165 non-null    object
#  11  Obesity         165 non-null    object
#  12  Hemochro        165 non-null    object
#  13  AHT             165 non-null    object
#  14  CRI             165 non-null    object
#  15  HIV             165 non-null    object
#  16  NASH            165 non-null    object
#  17  Varices         165 non-null    object
#  18  Spleno          165 non-null    object
#  19  PHT             165 non-null    object
#  20  PVT             165 non-null    object
#  21  Metastasis      165 non-null    object
#  22  Hallmark        165 non-null    object
#  23  Age             165 non-null    int64
#  24  Grams_day       165 non-null    object
#  25  Packs_year      165 non-null    object
#  26  PS              165 non-null    object
#  27  Encephalopathy  23 non-null     object
#  28  Ascites         56 non-null     object
#  29  INR             165 non-null    object
#  30  AFP             165 non-null    object
#  31  Hemoglobin      165 non-null    object
#  32  MCV             165 non-null    object
#  33  Leucocytes      165 non-null    object
#  34  Platelets       165 non-null    object
#  35   Albumin        165 non-null    object
#  36  Total_Bil       165 non-null    object
#  37  ALT             165 non-null    object
#  38  AST             165 non-null    object
#  39  GGT             165 non-null    object
#  40  ALP             165 non-null    object
#  41  TP              165 non-null    object
#  42  Creatinine      165 non-null    object
#  43  Nodules         165 non-null    object
#  44  Major_Dim       165 non-null    object
#  45  Dir_Bil         165 non-null    object
#  46  Iron            165 non-null    object
#  47  Sat             165 non-null    object
#  48  Ferritin        165 non-null    object
#  49  Class           165 non-null    object
# dtypes: int64(1), object(49)
# memory usage: 64.6+ KB

# %%
print(df.columns)
# Out:
# Index(['Gender', 'Symptoms', 'Alcohol', 'HBsAg', 'HBeAg', 'HBcAb', 'HCVAb',
#        'Cirrhosis', 'Endemic', 'Smoking', 'Diabetes', 'Obesity', 'Hemochro',
#        'AHT', 'CRI', 'HIV', 'NASH', 'Varices', 'Spleno', 'PHT', 'PVT',
#        'Metastasis', 'Hallmark', 'Age', 'Grams_day', 'Packs_year', 'PS',
#        'Encephalopathy', 'Ascites', 'INR', 'AFP', 'Hemoglobin', 'MCV',
#        'Leucocytes', 'Platelets', ' Albumin', 'Total_Bil', 'ALT', 'AST', 'GGT',
#        'ALP', 'TP', 'Creatinine', 'Nodules', 'Major_Dim', 'Dir_Bil', 'Iron',
#        'Sat', 'Ferritin', 'Class'],
#       dtype='object')

# %%
#The "Albumin" has a space before the name, so we need to remove it.
df.rename(columns={' Albumin':'Albumin'}, inplace=True)

# %%
#We observed that the data type of the columns are all 'object'. Looking at the data we can identify that there should have only categorical or numerical columns.
#To adress that we need to convert each column to correct type individually

# First, the ones that should be numerical:

numerical_columns = ['Age', 'Grams_day', 'Packs_year', 'INR', 'AFP', 'Hemoglobin', 'MCV', 'Leucocytes', 'Platelets', 'Albumin', 'Total_Bil', 'ALT', 'AST', 'GGT', 'ALP', 'TP', 'Creatinine', 'Nodules', 'Major_Dim', 'Dir_Bil', 'Iron', 'Sat', 'Ferritin']

for col in numerical_columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')           


# Second, the ones that should be categoyrical:
# Get the names of all columns that are not mentioned
non_numerical_columns = [col for col in df.columns if col not in numerical_columns]

# Convert these columns to 'category' data type
for col in non_numerical_columns:
    df[col] = df[col].astype('category')


# Check the new data type for each column (Note that dtype is still "object" because the dataframe has different types of data in it.)
print(df.dtypes)
# Out:
# Gender            category
# Symptoms          category
# Alcohol           category
# HBsAg             category
# HBeAg             category
# HBcAb             category
# HCVAb             category
# Cirrhosis         category
# Endemic           category
# Smoking           category
# Diabetes          category
# Obesity           category
# Hemochro          category
# AHT               category
# CRI               category
# HIV               category
# NASH              category
# Varices           category
# Spleno            category
# PHT               category
# PVT               category
# Metastasis        category
# Hallmark          category
# Age                  int64
# Grams_day          float64
# Packs_year         float64
# PS                category
# Encephalopathy    category
# Ascites           category
# INR                float64
# AFP                float64
# Hemoglobin         float64
# MCV                float64
# Leucocytes         float64
# Platelets          float64
# Albumin            float64
# Total_Bil          float64
# ALT                float64
# AST                float64
# GGT                float64
# ALP                float64
# TP                 float64
# Creatinine         float64
# Nodules            float64
# Major_Dim          float64
# Dir_Bil            float64
# Iron               float64
# Sat                float64
# Ferritin           float64
# Class             category
# dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for column in df.columns:
    plt.figure(figsize=(10,4))
    
    if df[column].dtype in ['int64', 'float64']:
        sns.boxplot(x=df[column])  # Boxplot for numerical data
    else:
        sns.countplot(x=df[column])  # Countplot for categorical data
    
    plt.title(f"Column: {column}")
    plt.show()

# Note that pandas internally maps the category values to integers. So a column that is categorical will be stored as integers in the dataframe, so here as we are prints it's values, will be displayed as integers but is indeed categorical.
# Out:
# c:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# c:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# c:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# c:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# c:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# c:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# c:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# c:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# c:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# c:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# c:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# c:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# c:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# c:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# c:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# c:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# c:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# c:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# c:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# c:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# c:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# c:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# c:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# c:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# c:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# c:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# c:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
# The statistics for the 'AFP' column suggest that there are outliers in the data. The maximum value (1,810,346) is much larger than the 75th percentile (615), and the standard deviation is also quite large, indicating a high level of variability in the data.

# The large difference between the maximum value and the 75th percentile is likely causing the boxplot to appear skewed. The box in the boxplot represents the interquartile range (from the 25th to the 75th percentile), and the whiskers typically extend to the most extreme data points within 1.5 times the interquartile range from the box. Data points outside this range are considered outliers and are plotted as individual points.

# To handle these outliers, we might consider: winsorizing, log transformation, removing outliers, or binning. However, it's important to understand why these outliers are present before deciding how to handle them. They could be due to data entry errors, or they could be valid data points that represent rare but important events.

print(df['AFP'].describe())

print(df['Leucocytes'].describe())
# Out:
# count    1.570000e+02
# mean     1.929995e+04
# std      1.490983e+05
# min      1.200000e+00
# 25%      5.200000e+00
# 50%      3.300000e+01
# 75%      6.150000e+02
# max      1.810346e+06
# Name: AFP, dtype: float64
# count      162.000000
# mean      1473.961549
# std       2909.106006
# min          2.200000
# 25%          5.100000
# 50%          7.200000
# 75%         19.525000
# max      13000.000000
# Name: Leucocytes, dtype: float64

# %%
#We can notice that there are '?' values in many columns of the dataset. These are assumed missing values. We need to handle them before we start to analyze the data. 

# List of columns with '?' as missing values

# Replace '?' with NaN throughout the dataframe
for col in df.columns:
   df[col] = df[col].replace('?', np.nan)

# uses .fillna (panda function) to change all '?' values to nan, the one above wasn't working as missing_value_columns wasn't defined


# Now we check the number of missing values in each column
print("Number of NaN per col")
print(df.isnull().sum())
# To make sure there is no '?' in the dataset you can run the code above.
# this is not working as intended. it's finding numeric values '0' and also counting them
# Out:
# Number of NaN per col
# Gender              0
# Symptoms           18
# Alcohol             0
# HBsAg              17
# HBeAg              39
# HBcAb              24
# HCVAb               9
# Cirrhosis           0
# Endemic            39
# Smoking            41
# Diabetes            3
# Obesity            10
# Hemochro           23
# AHT                 3
# CRI                 2
# HIV                14
# NASH               22
# Varices            52
# Spleno             15
# PHT                11
# PVT                 3
# Metastasis          4
# Hallmark            2
# Age                 0
# Grams_day          48
# Packs_year         53
# PS                  0
# Encephalopathy    143
# Ascites           111
# INR                 4
# AFP                 8
# Hemoglobin          3
# MCV                 3
# Leucocytes          3
# Platelets           3
# Albumin             6
# Total_Bil           5
# ALT                 4
# AST                 3
# GGT                 3
# ALP                 3
# TP                 11
# Creatinine          7
# Nodules             2
# Major_Dim          20
# Dir_Bil            44
# Iron               79
# Sat                80
# Ferritin           80
# Class               0
# dtype: int64

# %%
for col in df.columns:
    # if col has values equal to 0:
    if 0 in df[col].unique():
        print(f'{col}')
        print(f'Number of zeros: {df[col].value_counts()[0]}')
# Out:
# Grams_day
# Number of zeros: 43
# Packs_year
# Number of zeros: 61
# Nodules
# Number of zeros: 1
# Iron
# Number of zeros: 1
# Sat
# Number of zeros: 1
# Ferritin
# Number of zeros: 1

# %%
# Check if there are any remaining '?' values
remaining_question_marks = (df == '?').sum().sum()
print(f"Remaining '?' values: {remaining_question_marks}")

# Count the number of NaN values in each column
nan_counts = df.isnull().sum()
print("NaN counts per column:")
print(nan_counts)

# Total number of NaN values in the DataFrame
total_nan = df.isnull().sum().sum()
print(f"Total number of NaN values in the DataFrame: {total_nan}")
# Out:
# Remaining '?' values: 0
# NaN counts per column:
# Gender              0
# Symptoms           18
# Alcohol             0
# HBsAg              17
# HBeAg              39
# HBcAb              24
# HCVAb               9
# Cirrhosis           0
# Endemic            39
# Smoking            41
# Diabetes            3
# Obesity            10
# Hemochro           23
# AHT                 3
# CRI                 2
# HIV                14
# NASH               22
# Varices            52
# Spleno             15
# PHT                11
# PVT                 3
# Metastasis          4
# Hallmark            2
# Age                 0
# Grams_day          48
# Packs_year         53
# PS                  0
# Encephalopathy    143
# Ascites           111
# INR                 4
# AFP                 8
# Hemoglobin          3
# MCV                 3
# Leucocytes          3
# Platelets           3
# Albumin             6
# Total_Bil           5
# ALT                 4
# AST                 3
# GGT                 3
# ALP                 3
# TP                 11
# Creatinine          7
# Nodules             2
# Major_Dim          20
# Dir_Bil            44
# Iron               79
# Sat                80
# Ferritin           80
# Class               0
# dtype: int64
# Total number of NaN values in the DataFrame: 1077

# %%
#df.head(200)

# %%
#some columns arent standardized and need to be modified so we can compare the values, with a quick analysis, platelets and leucocytes aren't listed with correct values
'''
# Define a function to standardize values
def standardize_column(column, threshold):
    column_standardized = column.apply(lambda x: x / 1000 if x > threshold else x)
    return column_standardized

# Set thresholds
platelets_threshold = 1000  # Example threshold
leucocytes_threshold = 100  # Example threshold

#platelets = 10^9/L
# Standardize the columns
df['Platelets'] = standardize_column(df['Platelets'], platelets_threshold)
df['Leucocytes'] = standardize_column(df['Leucocytes'], leucocytes_threshold)

# Inspect the standardized columns
print("\nStandardized Platelets column:")
print(df['Platelets'])
print("\nStandardized Leucocytes column:")
print(df['Leucocytes'])
'''

#after checking the bibliography we chose not to alter this data and treat it as it is
# Out:
# '\n# Define a function to standardize values\ndef standardize_column(column, threshold):\n    column_standardized = column.apply(lambda x: x / 1000 if x > threshold else x)\n    return column_standardized\n\n# Set thresholds\nplatelets_threshold = 1000  # Example threshold\nleucocytes_threshold = 100  # Example threshold\n\n#platelets = 10^9/L\n# Standardize the columns\ndf[\'Platelets\'] = standardize_column(df[\'Platelets\'], platelets_threshold)\ndf[\'Leucocytes\'] = standardize_column(df[\'Leucocytes\'], leucocytes_threshold)\n\n# Inspect the standardized columns\nprint("\nStandardized Platelets column:")\nprint(df[\'Platelets\'])\nprint("\nStandardized Leucocytes column:")\nprint(df[\'Leucocytes\'])\n'

# %%
df.head(5)
# Out:
#    Gender Symptoms Alcohol HBsAg HBeAg HBcAb HCVAb Cirrhosis Endemic Smoking  \
# 0    Male       No     Yes    No    No    No    No       Yes      No     Yes
# 1  Female      NaN      No    No    No    No   Yes       Yes     NaN     NaN
# 2    Male       No     Yes   Yes    No   Yes    No       Yes      No     Yes
# 3    Male      Yes     Yes    No    No    No    No       Yes      No     Yes
# 4    Male      Yes     Yes   Yes    No   Yes    No       Yes      No     Yes
#
#   Diabetes Obesity Hemochro  AHT  CRI HIV NASH Varices Spleno  PHT PVT  \
# 0      Yes     NaN      Yes   No   No  No   No     Yes     No   No  No
# 1      Yes      No       No  Yes   No  No   No     Yes     No   No  No
# 2       No      No       No  Yes  Yes  No   No      No     No  Yes  No
# 3      Yes      No       No  Yes   No  No   No      No     No   No  No
# 4       No      No       No  Yes  Yes  No   No      No     No   No  No
#
#   Metastasis Hallmark  Age  Grams_day  Packs_year          PS Encephalopathy  \
# 0         No      Yes   67      137.0        15.0      Active            NaN
# 1         No      Yes   62        0.0         NaN      Active            NaN
# 2        Yes      Yes   78       50.0        50.0  Ambulatory            NaN
# 3        Yes      Yes   77       40.0        30.0      Active            NaN
# 4         No      Yes   76      100.0        30.0      Active            NaN
#
#   Ascites   INR     AFP  Hemoglobin    MCV  Leucocytes  Platelets  Albumin  \
# 0     NaN  1.53    95.0        13.7  106.6         4.9       99.0      3.4
# 1     NaN   NaN     NaN         NaN    NaN         NaN        NaN      NaN
# 2    Mild  0.96     5.8         8.9   79.8         8.4      472.0      3.3
# 3     NaN  0.95  2440.0        13.4   97.1         9.0      279.0      3.7
# 4     NaN  0.94    49.0        14.3   95.1         6.4      199.0      4.1
#
#    Total_Bil    ALT    AST    GGT    ALP   TP  Creatinine  Nodules  Major_Dim  \
# 0        2.1   34.0   41.0  183.0  150.0  7.1        0.70      1.0        3.5
# 1        NaN    NaN    NaN    NaN    NaN  NaN         NaN      1.0        1.8
# 2        0.4   58.0   68.0  202.0  109.0  7.0        2.10      5.0       13.0
# 3        0.4   16.0   64.0   94.0  174.0  8.1        1.11      2.0       15.7
# 4        0.7  147.0  306.0  173.0  109.0  6.9        1.80      1.0        9.0
#
#    Dir_Bil  Iron   Sat  Ferritin  Class
# 0      0.5   NaN   NaN       NaN  Lives
# 1      NaN   NaN   NaN       NaN  Lives
# 2      0.1  28.0   6.0      16.0  Lives
# 3      0.2   NaN   NaN       NaN   Dies
# 4      NaN  59.0  15.0      22.0  Lives

# %%
df.describe()
# Out:
#               Age   Grams_day  Packs_year         INR           AFP  \
# count  165.000000  117.000000  112.000000  161.000000  1.570000e+02
# mean    64.690909   71.008547   20.464286    1.421851  1.929995e+04
# std     13.319534   76.277680   51.565130    0.477816  1.490983e+05
# min     20.000000    0.000000    0.000000    0.840000  1.200000e+00
# 25%     57.000000    0.000000    0.000000    1.170000  5.200000e+00
# 50%     66.000000   75.000000    0.000000    1.300000  3.300000e+01
# 75%     74.000000  100.000000   30.500000    1.530000  6.150000e+02
# max     93.000000  500.000000  510.000000    4.820000  1.810346e+06
#
#        Hemoglobin         MCV    Leucocytes      Platelets     Albumin  \
# count  162.000000  162.000000    162.000000     162.000000  159.000000
# mean    12.879012   95.119753   1473.961549  113206.442654    3.445535
# std      2.145237    8.405846   2909.106006  107118.632481    0.685132
# min      5.000000   69.500000      2.200000       1.710000    1.900000
# 25%     11.425000   89.775000      5.100000     255.750000    3.000000
# 50%     13.050000   94.950000      7.200000   93000.000000    3.400000
# 75%     14.600000  100.675000     19.525000  171500.000000    4.050000
# max     18.700000  119.600000  13000.000000  459000.000000    4.900000
#
#         Total_Bil         ALT         AST          GGT         ALP  \
# count  160.000000  161.000000  162.000000   162.000000  162.000000
# mean     3.087938   67.093168   96.382716   268.026543  212.211605
# std      5.499379   57.539747   87.484241   258.750319  167.943548
# min      0.300000   11.000000   17.000000    23.000000    1.280000
# 25%      0.800000   31.000000   46.250000    91.250000  108.250000
# 50%      1.400000   50.000000   71.000000   179.500000  162.000000
# 75%      2.925000   78.000000  110.250000   345.250000  261.500000
# max     40.500000  420.000000  553.000000  1575.000000  980.000000
#
#                TP  Creatinine     Nodules   Major_Dim     Dir_Bil        Iron  \
# count  154.000000  158.000000  163.000000  145.000000  121.000000   86.000000
# mean     8.961039    1.127089    2.736196    6.851172    1.930000   85.598837
# std     11.728739    0.955856    1.797901    5.095042    4.210452   55.698995
# min      3.900000    0.200000    0.000000    1.500000    0.100000    0.000000
# 25%      6.300000    0.700000    1.000000    3.000000    0.370000   40.500000
# 50%      7.050000    0.850000    2.000000    5.000000    0.700000   83.000000
# 75%      7.575000    1.100000    5.000000    9.000000    1.400000  118.000000
# max    102.000000    7.600000    5.000000   22.000000   29.300000  224.000000
#
#               Sat     Ferritin
# count   85.000000    85.000000
# mean    37.028941   438.997647
# std     28.993552   457.114454
# min      0.000000     0.000000
# 25%     16.000000    84.000000
# 50%     27.000000   295.000000
# 75%     56.000000   706.000000
# max    126.000000  2230.000000

# %%
#About the call distribution, besides the info being above, we need to check the distribution of the target variable to see if it is balanced or not.
class_counts = df['Class'].value_counts()
class_counts.plot.pie(autopct='%1.1f%%')
plt.title('Class Distribution')
plt.ylabel('')

# Create a custom legend
legend_labels = [f'{cls} - {count}' for cls, count in zip(class_counts.index, class_counts)]
plt.legend(legend_labels, title="Classes", loc="best")

plt.show()

# %%
# # We observed that some numerical columns have outliers. We will use the Interquartile range method (IQR) to identify which are exacly and to handle these outliers.

#     # Explanation about the Interquartile range method (IQR) method:
#     # Sort your data from low to high.
#     # Identify the first quartile (Q1), the median, and the third quartile (Q3).
#     # Calculate your IQR = Q3 – Q1.
#     # Calculate your upper fence = Q3 + (1.5 * IQR)
#     # Calculate your lower fence = Q1 – (1.5 * IQR)
#     # Video to make it easy: https://www.youtube.com/watch?v=i7c2EQaKoqs

# Loop over all columns
# for column in df.columns:
    # Check if the column is numerical
#     if df[column].dtype in ['int64', 'float64']:
#         # Calculate Q1 (25th percentile) and Q3 (75th percentile)
#         Q1 = df[column].quantile(0.25)
#         Q3 = df[column].quantile(0.75)
#         IQR = Q3 - Q1

        # Define outliers as those outside of Q1 - 1.5 * IQR or Q3 + 1.5 * IQR
#         outliers = df[(df[column] < Q1 - 1.5 * IQR) | (df[column] > Q3 + 1.5 * IQR)][column]
#         print(f"Outliers in {column} based on IQR method:")
#         for index, value in outliers.items():
#             print(f"Index: {index}, Value: {value}")

        
# #Now we have three options to handle the outliers:
# #1. Remove the outliers from the dataset (Good if outilier are duo error in data collection/entry)
# # df = df[~((df[column] < Q1 - 1.5 * IQR) | (df[column] > Q3 + 1.5 * IQR))]

# #2. Replace the outliers with the median value of the column (good if the outliers are duo to data entry errors and you dont want to lose the data)
# # df[column] = np.where((df[column] < Q1 - 1.5 * IQR) | (df[column] > Q3 + 1.5 * IQR), df[column].median(), df[column])

# #3. Cap the outliers to a specified value  (good if the outliers are valid data points)
# # In this approach, we will assume that the data was collectec correctly but limit their value.
        
        # Cap the outliers to Q1 - 1.5 * IQR or Q3 + 1.5 * IQR
#         df[column] = np.where(df[column] < Q1 - 1.5 * IQR, Q1 - 1.5 * IQR, df[column])
#         df[column] = np.where(df[column] > Q3 + 1.5 * IQR, Q3 + 1.5 * IQR, df[column])
        
    
#     # Explanation about the Interquartile range method (IQR) method:
#     # Sort your data from low to high.
#     # Identify the first quartile (Q1), the median, and the third quartile (Q3).
#     # Calculate your IQR = Q3 – Q1.
#     # Calculate your upper fence = Q3 + (1.5 * IQR)
#     # Calculate your lower fence = Q1 – (1.5 * IQR)
#     # Video to make it easy: https://www.youtube.com/watch?v=i7c2EQaKoqs

# %%
import numpy as np

# Function to detect outliers using IQR
def detect_outliers_iqr(data):
    outliers_dict = {}
    for column in data.select_dtypes(include=[np.number]).columns:
        Q1 = data[column].quantile(0.25)
        Q3 = data[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]
        outliers_dict[column] = outliers
    return outliers_dict

# Detect outliers in the dataset
outliers = detect_outliers_iqr(df)

# Display columns with outliers and the count of outliers in each column
outliers_summary = {col: len(outliers[col]) for col in outliers if len(outliers[col]) > 0}

outliers_summary
# Out:
# {'Age': 4,
#  'Grams_day': 2,
#  'Packs_year': 3,
#  'INR': 9,
#  'AFP': 31,
#  'Hemoglobin': 1,
#  'MCV': 6,
#  'Leucocytes': 39,
#  'Platelets': 2,
#  'Total_Bil': 16,
#  'ALT': 12,
#  'AST': 13,
#  'GGT': 11,
#  'ALP': 11,
#  'TP': 9,
#  'Creatinine': 17,
#  'Major_Dim': 7,
#  'Dir_Bil': 14,
#  'Sat': 1,
#  'Ferritin': 2}

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

'''
label_encoder = LabelEncoder()

for col in non_numerical_columns:
    df[col] = label_encoder.fit_transform(df[col])

for col in non_numerical_columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')
'''

#converts the categorical data to numerical for better usage in machine learning
    
# Dictionary to store the label encoders and mappings
label_encoders = {}
label_mappings = {}

# Apply LabelEncoder to each categorical column
for col in non_numerical_columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le
    # Store the original mapping
    label_mappings[col] = {class_label: encoded_value for encoded_value, class_label in enumerate(le.classes_)}

print("Encoded DataFrame:")
print(df)

# Display the mappings
for col, mapping in label_mappings.items():
    print(f"\nMapping for {col}:")
    for class_label, encoded_value in mapping.items():
        print(f"{class_label} -> {encoded_value}")

#print(df.dtypes)
#the encoding is working, but the mapping is not working as intended, last resort is mapping by hand
#missing values are also being encoded
# Out:
# Encoded DataFrame:
#      Gender  Symptoms  Alcohol  HBsAg  HBeAg  HBcAb  HCVAb  Cirrhosis  \
# 0         1         0        1      0      0      0      0          1
# 1         0         2        0      0      0      0      1          1
# 2         1         0        1      1      0      1      0          1
# 3         1         1        1      0      0      0      0          1
# 4         1         1        1      1      0      1      0          1
# 5         1         0        1      0      2      0      0          1
# 6         1         0        0      0      2      1      1          1
# 7         1         1        1      0      2      0      0          1
# 8         1         1        1      0      0      0      0          1
# 9         1         1        1      0      0      0      0          1
# 10        1         0        1      0      0      0      1          1
# 11        1         0        1      0      0      0      1          1
# 12        1         0        1      0      0      0      0          1
# 13        1         2        0      0      0      0      1          1
# 14        1         0        1      0      0      0      0          1
# 18         78.0   3               2        2  1.130        8.80        14.9
# 19          NaN   0               2        1  1.440       34.00        15.9
# 20         60.0   0               2        2  1.290       19.60        11.7
# 21         47.0   0               2        2  1.060        3.90        16.4
# 22          0.0   3               2        1  1.270     1975.00        10.8
# 23         60.0   3               2        2  4.820      185.00        10.7
# 24          NaN   2               2        2  1.740     5532.00        13.1
# 25          0.0   1               2        2  1.330    13327.00        13.7
# 26         16.0   3               2        1  1.380         NaN        13.6
# 27          NaN   0               2        2  1.370        5.90        15.5
# 28         67.5   3               2        2  1.300     3255.00        12.2
# 29          2.0   3               2        2  1.210        1.90         9.9
# 30          8.0   1               2        2  1.190       11.00        13.1
# 31          NaN   0               2        2  1.440     1237.00        12.2
# 32          NaN   0               2        2  1.320        7.70        15.7
# 33          NaN   0               2        2  1.240      266.00        13.7
# 34          0.0   0               2        2  1.280     5689.00        14.3
# 35          0.0   0               2        2  0.960       14.20        14.8
# 36          0.0   2               2        0  2.000        3.10        13.1
# 37         30.0   3               2        0  1.240      633.00        13.0
# 38          0.0   0               2        2  1.090        5.40        14.9
# 39          0.0   0               2        2  1.420      479.00        11.3
# 40          0.0   0               2        2  1.180       19.00        13.9
# 41          0.0   0               2        2  1.210        2.80        15.7
# 42          NaN   4               2        2  1.200   185203.00        15.0
# 43          NaN   0               2        2  1.170        5.00        15.1
# 44          0.0   0               2        2  1.710      237.00        15.6
# 45          0.0   0               2        2  1.180        2.80        16.6
# 46          0.0   0               2        2    NaN         NaN         NaN
# 47          NaN   3               2        0  1.640       16.00        14.0
# 48         80.0   0               2        2  1.330      163.00        10.6
# 49         40.0   0               2        2  1.490       20.00        15.0
# 50          0.0   1               2        2  0.970       46.00        10.5
# 51          0.0   0               2        2  1.200    41470.00        12.6
# 52          0.0   0               2        2  1.330        4.70        11.8
# 53          0.0   0               2        2  1.650        7.30        15.3
# 54         30.0   4               2        0  1.350     1898.00        12.4
# 55          0.0   3               2        2  1.320       77.00        10.8
# 56         10.0   1               2        0  3.560        2.70         7.3
# 57          NaN   0               2        2  1.240        2.60        10.3
# 58          0.0   4               0        0  1.960       12.00        10.9
# 59          NaN   0               2        2  1.110         NaN        18.7
# 60         50.0   3               2        1  1.280      608.00        12.6
# 61         40.0   0               0        0  1.460       41.00        14.6
# 62         30.0   1               2        0  1.940         NaN        11.5
# 63          NaN   4               2        1  1.570        2.00        12.6
# 64          0.0   0               2        2  1.290        7.00        12.1
# 65          0.0   1               2        2  1.170        3.10        15.1
# 66          NaN   0               2        2  1.340       13.00        15.6
# 67          0.0   0               2        2  2.070        1.70         9.5
# 68          0.0   0               2        0  1.300      249.00        12.7
# 69          0.0   1               0        1  1.270       66.00        10.9
# 70          0.0   0               2        2  1.170      358.00        12.7
# 71         44.0   4               0        0  1.010  1810346.00        13.0
# 72         48.0   1               2        0  1.530    33502.00        14.4
# 73          0.0   0               2        2  0.940       20.00        13.0
# 74         15.0   0               2        2  1.150        2.50        14.9
# 75          NaN   0               2        2  1.920     2269.00        12.1
# 76          NaN   1               2        0  3.160     4181.00         9.1
# 77          NaN   0               2        2  1.450        5.10        14.4
# 78          NaN   4               2        2  1.340      345.00         9.8
# 79         34.5   1               0        0  2.080        2.90        10.4
# 80          NaN   4               0        2  1.320        2.50        12.6
# 81          NaN   3               0        2  1.630        5.04        15.8
# 82          0.0   3               2        1  1.710        3.70        14.8
# 83          NaN   1               2        1  1.480        2.60        12.7
# 84          NaN   0               2        2  1.100        2.90        16.4
# 85         10.0   3               0        2  1.470       20.00        13.9
# 86          NaN   3               2        2  1.080        2.79        12.6
# 87         33.0   0               2        0    NaN       42.00        15.8
# 88          NaN   0               2        0  1.370      457.00        11.7
# 89         50.0   3               0        1  1.230         NaN         9.5
# 90          0.0   1               2        1  1.410      123.00        10.1
# 91          NaN   0               2        2  1.220        8.70        14.6
# 92          0.0   4               2        2  1.010      226.00        11.5
# 93         60.0   3               2        2  1.390     2159.00        13.1
# 94         50.0   0               2        2  1.090       48.00        12.6
# 95          0.0   3               2        2  1.600        2.40         9.5
# 96          0.0   3               2        0  1.110        5.00         9.1
# 97          NaN   0               2        2  1.640       64.00        14.1
# 98          NaN   0               2        2  1.230        5.50        13.1
# 99          0.0   1               2        0  1.670        8.50        13.0
# 100         0.0   1               2        2  1.160     2785.00        12.0
# 101         NaN   3               2        1  1.040     6574.00        13.5
# 102         NaN   1               2        0  1.550        5.70        13.9
# 103         NaN   2               1        1  1.930         NaN        13.5
# 104        50.0   3               2        2  1.170       39.00        12.6
# 105         0.0   4               2        0  1.480        2.50        14.3
# 106         1.0   0               2        2  1.180       32.00        14.0
# 107         0.0   4               2        0  1.320        7.60         5.0
# 108         0.0   3               2        2  1.250      173.00        11.3
# 109         NaN   0               2        2  1.540        2.30        12.1
# 110        30.0   1               0        0  1.260      114.00        14.9
# 111         NaN   1               2        0  1.870      173.00        11.1
# 112         NaN   0               2        2  1.360       18.00        15.3
# 113         7.5   3               2        2  1.450       42.00        16.2
# 114         NaN   4               1        0  1.870    28274.00        10.3
# 115        43.0   0               2        2  1.230      736.00        14.0
# 116        60.0   0               2        1  1.170     1009.00        13.8
# 117         NaN   2               1        0  2.420    22475.00        12.0
# 118         0.0   0               2        2  1.280        5.20        14.6
# 119        23.0   0               2        0  1.460        5.20        14.9
# 120         0.0   3               2        2  1.140    14177.00        10.2
# 121         0.0   0               2        2  1.940        3.10        10.8
# 122        52.5   1               2        2  1.560    50655.00         9.8
# 123         0.0   0               2        2  1.110        1.20        15.1
# 124         NaN   1               2        0  1.080      657.00        11.8
# 125         NaN   2               0        0  1.200   421500.00        14.3
# 126         NaN   0               2        2  1.200      472.00        15.6
# 127         0.0   4               0        2  1.660       77.00        12.3
# 128       510.0   1               2        2  1.130        2.10        12.6
# 129         0.0   1               0        0  1.070        2.00        11.6
# 130         0.0   1               2        1  1.220        4.20        14.9
# 131         NaN   1               0        0  2.500        7.50        11.3
# 132         0.0   0               2        2  1.210      152.00        10.9
# 133         0.0   3               2        2  1.090      811.00        11.4
# 134         0.0   0               2        2  1.420        4.70        14.2
# 135         0.0   3               2        2  1.240        2.60        13.3
# 136        40.0   1               2        2  1.250     2089.00        15.4
# 137         0.0   0               0        2  1.030       18.00        13.2
# 138         NaN   0               2        2  1.190        4.90        13.6
# 139        12.0   1               2        2  0.940      240.00        14.7
# 140         0.0   0               2        2  1.250      180.00        12.2
# 141         NaN   0               2        2  1.470       15.00        13.3
# 142         0.0   0               2        2  1.020       24.00        16.0
# 143        40.0   0               2        2  1.798        9.40        11.2
# ...
# 26   172.00    8.1        0.83      1.0       5.00     0.70    NaN     NaN
# 27   111.00    NaN         NaN      2.0       4.00     1.00  180.0   56.00
# 28   293.00    7.7        0.67      2.0       6.50     0.40   94.0   27.00
# 29   974.00    7.7        0.70      5.0        NaN     1.10   22.0    7.00
# 30   158.00    8.2        0.71      1.0      16.00      NaN    NaN     NaN
# 31   129.00   58.0        1.06      5.0       7.00      NaN   75.0   24.00
# 32   135.00    8.2        0.90      2.0        NaN      NaN    NaN     NaN
# 33   227.00   16.8        1.72      1.0       5.90      NaN    NaN     NaN
# 34   184.00    6.9        0.89      2.0       3.00     0.77    NaN     NaN
# 35   113.00    6.7        0.95      3.0       8.80     0.37    NaN     NaN
# 36   127.00    5.6        0.88      5.0       3.10     3.30   98.0   89.00
# 37   209.00    6.7        1.40      5.0       4.90     0.20   57.0   25.00
# 38    92.00    7.3        0.80      2.0       6.00     0.30    NaN     NaN
# 39   288.00    7.9        0.98      5.0      17.00     0.60    NaN     NaN
# 40   104.00    8.5        0.74      2.0       3.30     0.30  143.0   50.18
# 41    68.00    6.5        1.30      1.0       5.00     0.30    NaN     NaN
# 42   278.00    7.2        0.86      5.0      15.80     0.30   21.0    9.00
# 43    56.00    7.3        0.70      1.0       2.00     0.20    NaN     NaN
# 44    97.00    6.7        0.86      5.0       2.20     0.50    NaN     NaN
# 45    68.00    8.3        0.72      1.0       2.30      NaN    NaN     NaN
# 46      NaN    NaN         NaN      NaN        NaN      NaN    NaN     NaN
# 47   595.00    7.2        0.79      1.0       2.30     4.10   63.0   34.00
# 48   171.00    7.5        1.38      1.0      19.00      NaN   45.0   21.00
# 49   109.00    7.6        0.80      1.0       2.00     0.40  184.0   59.00
# 50   539.00    5.0        0.38      5.0      20.00     0.30    NaN     NaN
# 51   350.00    7.3        1.70      5.0        NaN     0.80   84.0   37.00
# 52    62.00    7.4        0.77      1.0       2.30      NaN  104.0   37.00
# 53   130.00    NaN        0.76      2.0       2.00     0.30  184.0    2.26
# 54   397.00    6.7        0.82      1.0       2.10     5.50   56.0   27.00
# 55   923.00    5.4        1.31      3.0      15.40      NaN    NaN     NaN
# 56    55.00    6.2        0.85      1.0       2.20      NaN   22.0    6.00
# 57   120.00    7.0        0.58      1.0       4.70     0.85   32.0   10.00
# 58   263.00    7.0        0.99      1.0       8.50     1.90   44.0   20.00
# 59   103.00    6.8        1.24      1.0      10.00      NaN    NaN     NaN
# 60   100.00    7.5        0.90      5.0       3.50     0.50    NaN     NaN
# 61   207.00    6.3        0.69      1.0       3.00     1.90  224.0   95.00
# 62   178.00    6.1        0.62      1.0       4.60     2.20    NaN     NaN
# 63   166.00    NaN        0.77      1.0       2.00     0.50    NaN     NaN
# 64   161.00    6.7        0.71      1.0      10.00     0.50    0.0    0.00
# 65   104.00    5.4        0.60      5.0       7.80     0.20   46.0   18.00
# 66   113.00    7.8        0.55      2.0       6.20     0.30   94.0   33.00
# 67   113.00   37.0        0.40      1.0       2.70     0.20   94.0   37.00
# 68   108.00    5.8        0.90      5.0       8.00     1.20   37.0   17.00
# 69   260.00    5.9         NaN      5.0       3.00     1.30   15.0   17.00
# 70    94.00    4.9        0.20      2.0       5.40     0.80   50.0   16.00
# 71   417.00    6.5        0.64      5.0      15.00     1.10    NaN     NaN
# 72     1.28    6.7        1.50      5.0       4.00     0.80   26.0   15.00
# 73   684.00    7.1        0.81      5.0        NaN      NaN    NaN     NaN
# 74   101.00    7.4        1.10      5.0       7.50     0.30   61.0     NaN
# 75   174.00    NaN        0.99      1.0       7.60     4.60  178.0   90.00
# 76   165.00    7.7        0.83      1.0       4.50     1.20   72.0   29.50
# 77   114.00    7.0        1.09      5.0        NaN      NaN    NaN     NaN
# 78    88.00    5.6         NaN      5.0       4.70     0.50   19.0    8.00
# 79   190.00    5.9        0.90      0.0        NaN     9.60    NaN     NaN
# 80   204.00    7.3        1.10      5.0        NaN     0.50    NaN     NaN
# 81   165.00    6.6        0.70      1.0       6.00     1.70  200.0   87.00
# 82   280.00    8.0        0.80      2.0       3.00     1.40    NaN    1.52
# 83   207.00    7.2         NaN      2.0       4.10     1.40  105.0   69.00
# 84    85.00    7.9        1.05      1.0       5.50     0.30    NaN     NaN
# 85   244.00    6.3        0.80      2.0       6.80     0.70  181.0   99.00
# 86   213.00    NaN        0.48      5.0        NaN      NaN   26.0    8.00
# 87    70.00    7.5        0.77      3.0       1.50      NaN  120.0   35.00
# 88    90.00    9.7        1.60      5.0       5.60     0.90   13.0    3.00
# 89   474.00    3.9        2.69      1.0       2.00     1.00    NaN     NaN
# 90   177.00    6.8        0.70      3.0       3.50     1.00   37.0   11.00
# 91   120.00    7.8        0.83      NaN        NaN     0.30  184.0   65.00
# 92   222.00    6.2        3.13      1.0       8.80     0.20    NaN     NaN
# 93   335.00    7.1        0.68      5.0        NaN     0.60    NaN     NaN
# 94    91.00    6.9        1.90      5.0       2.00      NaN   53.0   21.00
# 95   124.00    6.8        1.60      1.0       5.50      NaN   15.0    7.00
# 96   254.00    5.5        1.18      3.0       6.30      NaN    NaN     NaN
# 97   137.00    6.8        0.67      4.0       4.70     1.10    NaN     NaN
# 98    92.00    6.3        0.86      5.0        NaN      NaN   93.0   25.00
# 99    66.00    6.1        1.20      5.0       7.00     5.50    NaN     NaN
# 100  297.00    5.7        2.19      5.0        NaN     1.50   55.0   33.00
# 101  262.00    6.9        1.20      5.0       4.00    19.50  121.0   27.00
# 102  110.00    5.0        0.56      3.0       2.40      NaN   92.0   56.00
# 103  670.00    6.3        4.82      5.0        NaN    29.30    NaN     NaN
# 104  312.00   78.0        1.01      1.0      15.00      NaN   87.0   25.00
# 105   97.00    5.2        2.82      3.0       2.40     0.30   92.0   56.00
# 106  174.00    8.6        0.90      5.0       3.00      NaN   26.4   54.00
# 107   86.00    6.3        2.68      1.0      10.00      NaN    9.0    3.00
# 108  163.00    6.1        0.67      5.0      20.00     0.50  131.0   78.00
# 109  120.00    4.3        0.61      5.0       4.00     0.70    NaN     NaN
# 110  166.00    7.2        0.48      5.0      12.60     1.80  161.0   96.00
# 111  188.00    5.4        1.29      5.0        NaN    22.10    NaN     NaN
# 112  109.00    7.3        1.02      1.0       3.50     0.30    NaN     NaN
# 113  158.00    7.7        0.88      2.0       7.40     0.30    NaN     NaN
# 114  128.00    7.0        1.30      1.0       1.50     1.90   51.0   18.00
# 115  629.00    8.4        0.71      5.0       9.10     0.30    NaN     NaN
# 116  235.00    NaN        0.79      2.0      20.00      NaN    NaN     NaN
# 117  146.00    8.0        3.23      1.0        NaN     9.70  106.0   67.00
# 118   79.00    7.7        1.02      1.0       3.00      NaN    NaN     NaN
# 119  239.00    8.1        0.72      1.0       1.50     1.00    NaN     NaN
# 120  980.00    7.5        0.78      5.0       9.00     2.80    NaN     NaN
# 121  433.00    6.5        0.87      2.0       3.20     0.40   52.5   37.00
# 122  363.00    7.3        0.55      1.0       4.00     1.50   40.0   12.00
# 123  151.00    6.4        1.50      1.0       8.30      NaN   88.0   27.00
# 124  466.00    7.3        0.70      1.0       8.30      NaN    NaN     NaN
# 125  217.00    6.3        0.70      1.0      20.00     0.50   52.0   17.00
# 126  117.00    7.2        0.69      1.0      13.00     0.70    NaN     NaN
# 127  182.00    6.2        0.77      2.0       4.30     1.00   93.0   47.00
# 128  127.00    6.9        1.11      2.0       4.30      NaN   28.0   10.00
# 129  171.00    7.1        0.66      2.0       5.80      NaN    NaN     NaN
# 130  150.00    5.4        0.70      5.0      17.50     0.30    NaN     NaN
# 131  147.00    6.5        1.00      5.0       2.60     3.80    NaN     NaN
# 132  106.00    7.1        6.10      2.0       9.00     0.70    NaN     NaN
# 133  587.00    7.2        2.14      5.0      16.00      NaN   14.0    5.00
# 134  517.00    5.5        0.70      1.0      13.00     0.12    NaN     NaN
# 135  123.00    6.8        0.82      5.0       8.30      NaN    NaN     NaN
# 136  295.00    7.4        1.10      5.0       6.00     0.60    NaN     NaN
# 137  141.00    7.2        0.85      1.0       9.50      NaN   91.0   31.00
# 138   89.00    7.8        0.78      2.0       3.32      NaN   78.0   30.00
# 139  192.00    7.4        0.90      3.0       2.00     0.40    NaN     NaN
# 140  302.00    7.0        0.60      5.0       9.00      NaN    NaN     NaN
# 141  108.00  102.0        0.68      3.0       2.00      NaN    NaN     NaN
# 142   84.00    7.2        0.90      1.0       2.20     0.30    NaN     NaN
# 143  106.00    7.6        0.52      1.0       2.10     1.10   94.0   39.00
# 144   93.00    6.4        1.00      3.0       2.90     0.40  124.0   51.00
# 145  141.00    NaN        1.10      1.0      15.00     0.33    NaN     NaN
# 146  472.00    5.9        2.02      1.0        NaN     0.60   29.0    4.00
# 147  117.00    7.1        0.79      1.0       3.50     1.00    NaN     NaN
# 148  105.00    7.6        0.53      1.0       2.40     0.30    NaN     NaN
# 149     NaN    NaN         NaN      1.0       6.60      NaN    NaN     NaN
# 150   79.00    7.3        1.00      1.0        NaN     0.20    NaN     NaN
# 151   85.00    7.6        0.80      1.0       7.00     0.40    NaN     NaN
# 152   44.00    7.0        0.96      5.0       3.50      NaN    NaN     NaN
# 153  338.00    7.0        1.13      1.0      15.00     1.30    NaN     NaN
# 154  318.00    6.4        0.64      5.0       1.90     1.00    NaN     NaN
# 155  139.00    7.6        0.90      3.0       9.00     2.90  111.0   94.00
# 156  266.00    7.5        0.77      1.0       2.30     0.60  180.0   70.00
# 157   97.00    7.3        0.76      1.0       3.50     0.30    NaN     NaN
# 158  263.00    6.8        1.49      1.0       7.50      NaN    NaN     NaN
# 159   73.00    4.8        0.77      5.0       3.20     0.70   40.0   18.00
# 160  109.00    7.6        0.70      5.0       3.00      NaN    NaN     NaN
# 161  280.00    6.7        0.70      1.0       2.20     2.30    NaN     NaN
# 162  181.00    7.5        1.46      5.0      18.60      NaN    NaN     NaN
# 163  170.00    8.4        0.74      5.0      18.00      NaN    NaN     NaN
# 164  462.00    6.6        3.95      5.0       8.50    19.80    NaN     NaN
#
#      Ferritin  Class
# 0         NaN      1
# 1         NaN      1
# 2        16.0      1
# 3         NaN      0
# 4        22.0      1
# 5       111.0      0
# 6      1452.0      0
# 7       706.0      0
# 8       982.0      1
# 9         NaN      1
# 10        NaN      0
# 11      277.0      1
# 12        NaN      1
# 13        NaN      1
# 14      302.0      1
# 15       60.0      1
# 16      767.0      0
# 17      443.0      1
# 18      295.0      1
# 19      774.0      0
# 20       76.9      1
# 21       84.0      1
# 22     1001.0      0
# 23        NaN      0
# 24        NaN      0
# 25       79.0      1
# 26        NaN      0
# 27        NaN      1
# 28       70.0      0
# 29      369.0      1
# 30        NaN      1
# 31      239.0      1
# 32        NaN      1
# 33        NaN      1
# 34        NaN      1
# 35        NaN      1
# 36      870.0      0
# 37      134.0      0
# 38        NaN      1
# 39        NaN      1
# 40      120.0      1
# 41        NaN      1
# 42      279.0      0
# 43        NaN      1
# 44        NaN      1
# 45        NaN      1
# 46        NaN      1
# 47      888.0      0
# 48      802.0      0
# 49      905.0      1
# 50        NaN      0
# 51      497.0      0
# 52      635.0      1
# 53       59.0      1
# 54      742.0      0
# 55        NaN      0
# 56       48.0      0
# 57       18.0      1
# 58      176.0      0
# 59        NaN      0
# 60        NaN      1
# 61      363.0      1
# 62        NaN      1
# 63        NaN      1
# 64        0.0      1
# 65        NaN      0
# 66      393.0      1
# 67       48.0      1
# 68      419.0      0
# 69      639.0      0
# 70       20.0      1
# 71        NaN      1
# 72      227.0      1
# 73        NaN      0
# 74      255.0      1
# 75      960.0      0
# 76      355.0      0
# 77        NaN      1
# 78      141.0      1
# 79        NaN      1
# 80        NaN      0
# 81      316.0      1
# 82      859.0      1
# 83      221.0      0
# 84        NaN      1
# 85      108.0      1
# 86        NaN      1
# 87       30.0      1
# 88       28.0      0
# 89        NaN      1
# 90      173.0      0
# 91      423.0      1
# 92        NaN      0
# 93        NaN      0
# 94      278.0      1
# 95      810.0      0
# 96        NaN      1
# 97        NaN      1
# 98       29.0      1
# 99        NaN      1
# 100     256.0      1
# 101     749.0      0
# 102     489.0      1
# 103       NaN      0
# 104      81.0      1
# 105      48.9      1
# 106    2230.0      1
# 107     490.0      0
# 108    1316.0      0
# 109       NaN      1
# 110     297.0      1
# 111       NaN      0
# 112       NaN      1
# 113       NaN      1
# 114      56.0      0
# 115       NaN      1
# 116       NaN      0
# 117    2165.0      0
# 118       NaN      1
# 119       NaN      1
# 120       NaN      1
# 121     856.0      0
# 122      57.0      0
# 123      90.0      1
# 124     579.0      0
# 125     832.0      0
# 126       NaN      1
# 127     307.0      1
# 128     308.0      0
# 129       NaN      0
# 130       NaN      1
# 131       NaN      1
# 132       NaN      0
# 133     149.0      0
# 134       NaN      1
# 135       NaN      1
# 136       NaN      1
# 137      80.0      1
# 138     220.0      1
# 139       NaN      1
# 140     206.0      0
# 141       NaN      0
# 142       NaN      1
# 143     344.0      1
# 144     642.0      1
# 145       NaN      1
# 146      14.0      0
# 147       NaN      1
# 148       NaN      1
# 149       NaN      1
# 150       NaN      1
# 151       NaN      1
# 152       NaN      1
# 153       NaN      0
# 154       NaN      1
# 155    1600.0      0
# 156    1176.0      0
# 157       NaN      1
# 158       NaN      1
# 159     283.0      0
# 160       NaN      1
# 161       NaN      0
# 162       NaN      1
# 163       NaN      0
# 164       NaN      0
#
# Mapping for Gender:
# Female -> 0
# Male -> 1
#
# Mapping for Symptoms:
# No -> 0
# Yes -> 1
# nan -> 2
#
# Mapping for Alcohol:
# No -> 0
# Yes -> 1
#
# Mapping for HBsAg:
# No -> 0
# Yes -> 1
# nan -> 2
#
# Mapping for HBeAg:
# No -> 0
# Yes -> 1
# nan -> 2
#
# Mapping for HBcAb:
# No -> 0
# Yes -> 1
# nan -> 2
#
# Mapping for HCVAb:
# No -> 0
# Yes -> 1
# nan -> 2
#
# Mapping for Cirrhosis:
# No -> 0
# Yes -> 1
#
# Mapping for Endemic:
# No -> 0
# Yes -> 1
# nan -> 2
#
# Mapping for Smoking:
# No -> 0
# Yes -> 1
# nan -> 2
#
# Mapping for Diabetes:
# No -> 0
# Yes -> 1
# nan -> 2
#
# Mapping for Obesity:
# No -> 0
# Yes -> 1
# nan -> 2
#
# Mapping for Hemochro:
# No -> 0
# Yes -> 1
# nan -> 2
#
# Mapping for AHT:
# No -> 0
# Yes -> 1
# nan -> 2
#
# Mapping for CRI:
# No -> 0
# Yes -> 1
# nan -> 2
#
# Mapping for HIV:
# No -> 0
# Yes -> 1
# nan -> 2
#
# Mapping for NASH:
# No -> 0
# Yes -> 1
# nan -> 2
#
# Mapping for Varices:
# No -> 0
# Yes -> 1
# nan -> 2
#
# Mapping for Spleno:
# No -> 0
# Yes -> 1
# nan -> 2
#
# Mapping for PHT:
# No -> 0
# Yes -> 1
# nan -> 2
#
# Mapping for PVT:
# No -> 0
# Yes -> 1
# nan -> 2
#
# Mapping for Metastasis:
# No -> 0
# Yes -> 1
# nan -> 2
#
# Mapping for Hallmark:
# No -> 0
# Yes -> 1
# nan -> 2
#
# Mapping for PS:
# Active -> 0
# Ambulatory -> 1
# Disabled -> 2
# Restricted -> 3
# Selfcare -> 4
#
# Mapping for Encephalopathy:
# Grade I/II -> 0
# Grade III/IV -> 1
# nan -> 2
#
# Mapping for Ascites:
# Mild -> 0
# Moderate/Severe -> 1
# nan -> 2
#
# Mapping for Class:
# Dies -> 0
# Lives -> 1

# %%
df.describe()
# Out:
#            Gender    Symptoms     Alcohol       HBsAg       HBeAg       HBcAb  \
# count  165.000000  165.000000  165.000000  165.000000  165.000000  165.000000
# mean     0.806061    0.787879    0.739394    0.303030    0.478788    0.521212
# std      0.396586    0.622621    0.440302    0.647926    0.852456    0.737397
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      1.000000    1.000000    1.000000    0.000000    0.000000    0.000000
# 75%      1.000000    1.000000    1.000000    0.000000    0.000000    1.000000
# max      1.000000    2.000000    1.000000    2.000000    2.000000    2.000000
#
#             HCVAb   Cirrhosis     Endemic     Smoking    Diabetes     Obesity  \
# count  165.000000  165.000000  165.000000  165.000000  165.000000  165.000000
# mean     0.315152    0.903030    0.533333    0.878788    0.375758    0.242424
# std      0.571754    0.296817    0.852066    0.779211    0.522091    0.553828
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 75%      1.000000    1.000000    1.000000    1.000000    1.000000    0.000000
# max      2.000000    1.000000    2.000000    2.000000    2.000000    2.000000
#
#          Hemochro         AHT         CRI         HIV        NASH     Varices  \
# count  165.000000  165.000000  165.000000  165.000000  165.000000  165.000000
# mean     0.321212    0.393939    0.145455    0.187879    0.315152    1.048485
# std      0.707002    0.526111    0.386582    0.569423    0.696735    0.763545
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000    1.000000
# 75%      0.000000    1.000000    0.000000    0.000000    0.000000    2.000000
# max      2.000000    2.000000    2.000000    2.000000    2.000000    2.000000
#
#            Spleno         PHT         PVT  Metastasis    Hallmark         Age  \
# count  165.000000  165.000000  165.000000  165.000000  165.000000  165.000000
# mean